# %% [markdown]
# <center>
#     <h1>TP4</h1>
#     <h2>Clustering de données</h2>
# </center>

# %% [markdown]
# ## K-Moyennes

# %%
from sklearn import *
import numpy as np
import matplotlib.pyplot as plt

iris = datasets.load_iris()
X = iris.data
y = iris.target

# %%
def d_euclidean(A,B):
    return metrics.pairwise.euclidean_distances([A],[B])[0][0]

# %%
from scipy.spatial.distance import euclidean
def k_moyennes(data, k, max_iter = 100):
    n_iter = 0
    centroids = {}
    for i in range(k): centroids[i] = data[i]
    for i in range(max_iter):
        classes = {}
        targests = {}
        for j in range(k):
            classes[j] = []
            targests[j] = []
        for j in range(len(data)):
            distances = [d_euclidean(data[j], centroids[cen]) for cen in centroids]
            classe = np.argmin(distances)
            classes[classe].append(data[j])
            targests[classe].append(j)
        prev_centroids = dict(centroids)
        for classe in classes:
            centroids[classe] = np.mean(classes[classe], axis=0)
        
        for c in centroids:
            original_centroid = prev_centroids[c]
            current_centroid = centroids[c]
        
        ccens = np.array([v for v in centroids.values()])
        pcens = np.array([v for v in prev_centroids.values()])
        n_iter += 1
        
        if (ccens == pcens).all():
            break
        
    for k,v in classes.items(): classes[k] = np.array(v)
    return targests, n_iter

targests, n_iter = k_moyennes(X,3)
print(n_iter)
# Out:
# 12

# %%
y_pred = []
l = []
for k,v in targests.items(): 
    l.append(v)
l.reverse()
for i in range(len(l)):
    for j in range(len(l[i])):
        y_pred.append(i)
        
y_pred = np.array(y_pred)

error = 1 - metrics.accuracy_score(y_pred, y)
print(f"error = {round(error, 2)} %")
silhouette_avg = metrics.silhouette_score(X, y_pred)
print(silhouette_avg)
# Out:
# error = 0.07 %
# 0.41773509378839796

# %%
def get_meilleur_score():
    scores = []
    for i in range(2, 11):
        for j in range(10):
            kmeans = cluster.KMeans(n_clusters=i).fit(X)
            pred = kmeans.fit_predict(X)
            score = metrics.silhouette_score(X, pred)
            scores.append((j+1,i,score))
            #print(f"{k} - Pour {i} clusters, score = {score}")
    scores.sort(key = lambda x:x[2], reverse=True)
    return scores[0]

# %%
(iterations, n_clusters, score) = get_meilleur_score()

# %%
print(f"le meilleur score = {score} dont le nombre des clusters est {n_clusters} dans l'iteration numero {iterations}")
# Out:
# le meilleur score = 0.681046169211746 dont le nombre des clusters est 2 dans l'iteration numero 1

# %%
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
import matplotlib.pyplot as plt

pca = PCA(n_components=2)
lda = LDA(n_components=2)

irisPCA = pca.fit(X).transform(X)
irisLDA = lda.fit(X,y_pred).transform(X)

fig = plt.figure(figsize=(16,8))
plt.subplot(121); plt.scatter(irisPCA[:,0], irisPCA[:,1], c=y_pred); plt.title('P C A'); plt.xlabel('X'); plt.ylabel('y')
plt.subplot(122); plt.scatter(irisLDA[:,0], irisLDA[:,1], c=y_pred); plt.title('L D A'); plt.xlabel('X'); plt.ylabel('y')
plt.show()

# %% [markdown]
# ## Analyse des données « choix projet »
